# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
path = 'sinewave.csv'
# 使用pandas读入
data = pd.read_csv(path) #读取文件中所有数据
# 按列分离数据
# x = data[['ImageID', 'label']]#读取某两列
# print(x)
x=np.linspace(-5,5,1000)
y = data.iloc[0:1000, 0]
plt.plot(x,y)
plt.title("part of data")
plt.savefig(os.path.join('/home/wengchuang/下载/神经网络/final/homework/final/images/', 'sin.jpg'))
plt.show()
