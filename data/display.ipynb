# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
path = 'sinewave.csv'
# 使用pandas读入
data = pd.read_csv(path) #读取文件中所有数据
# 按列分离数据
# x = data[['ImageID', 'label']]#读取某两列
# print(x)
x=np.linspace(-5,5,1000)
y = data.iloc[0:1000, 0]
print(y)
plt.plot(x,y)
plt.title("part of data")
plt.show()
plt.savefig(os.path.join('sin.jpg'))
# Out:
# 0      0.873736
# 1      0.902554
# 2      0.927809
# 3      0.949402
# 4      0.967249
#          ...
# 995    0.680667
# 996    0.725324
# 997    0.767118
# 998    0.805885
# 999    0.841471
# Name: sinewave, Length: 1000, dtype: float64
